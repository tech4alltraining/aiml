# %% [markdown]
# **Trainer Notebook**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('https://raw.githubusercontent.com/tech4alltraining/aiml/refs/heads/main/datasets/loan_data_10k.csv')
df
# Out:
#       person_age person_gender person_education  person_income  \
# 0             29        female        Associate        39704.0
# 1             28          male        Associate        36889.0
# 2             26          male        Associate        97163.0
# 3             41          male        Doctorate        65605.0
# 4             24          male         Bachelor        37030.0
# ...          ...           ...              ...            ...
# 9995          27          male         Bachelor        83946.0
# 9996          25          male           Master        38201.0
# 9997          37          male        Associate        71970.0
# 9998          28          male           Master        96968.0
# 9999          29          male           Master        44389.0
#
#       person_emp_exp person_home_ownership  loan_amnt loan_intent  \
# 0                  8                  RENT    10800.0     MEDICAL
# 1                  5                  RENT     7796.0    PERSONAL
# ...

# %%
df.head()
# Out:
#    person_age person_gender person_education  person_income  person_emp_exp  \
# 0          29        female        Associate        39704.0               8
# 1          28          male        Associate        36889.0               5
# 2          26          male        Associate        97163.0               2
# 3          41          male        Doctorate        65605.0              23
# 4          24          male         Bachelor        37030.0               1
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 0                  RENT    10800.0     MEDICAL          13.57
# 1                  RENT     7796.0    PERSONAL          14.04
# 2                  RENT    20000.0   EDUCATION          10.05
# 3                  RENT    10000.0     MEDICAL          13.23
# 4                  RENT     4600.0     MEDICAL          11.01
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 0                 0.27                           5           607
# ...

# %%
df.tail()
# Out:
#       person_age person_gender person_education  person_income  \
# 9995          27          male         Bachelor        83946.0
# 9996          25          male           Master        38201.0
# 9997          37          male        Associate        71970.0
# 9998          28          male           Master        96968.0
# 9999          29          male           Master        44389.0
#
#       person_emp_exp person_home_ownership  loan_amnt loan_intent  \
# 9995               3                  RENT     9000.0    PERSONAL
# 9996               5                  RENT    11200.0     VENTURE
# 9997              18                  RENT     5000.0    PERSONAL
# 9998               5              MORTGAGE    16000.0    PERSONAL
# 9999               6                  RENT    15207.0    PERSONAL
#
#       loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 9995          16.77                 0.11                           6
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   person_age                      10000 non-null  int64
#  1   person_gender                   9999 non-null   object
#  2   person_education                10000 non-null  object
#  3   person_income                   10000 non-null  float64
#  4   person_emp_exp                  10000 non-null  int64
#  5   person_home_ownership           10000 non-null  object
#  6   loan_amnt                       10000 non-null  float64
#  7   loan_intent                     10000 non-null  object
#  8   loan_int_rate                   9999 non-null   float64
#  9   loan_percent_income             9999 non-null   float64
#  10  cb_person_cred_hist_length      10000 non-null  int64
#  11  credit_score                    10000 non-null  int64
# ...

# %%
df.describe(include='all')
# Out:
#           person_age person_gender person_education  person_income  \
# count   10000.000000          9999            10000   1.000000e+04
# unique           NaN             2                5            NaN
# top              NaN          male         Bachelor            NaN
# freq             NaN          5561             3011            NaN
# mean       27.696600           NaN              NaN   7.228964e+04
# std         6.038758           NaN              NaN   5.846243e+04
# min        20.000000           NaN              NaN   8.000000e+03
# 25%        24.000000           NaN              NaN   4.162175e+04
# 50%        26.000000           NaN              NaN   6.095400e+04
# 75%        30.000000           NaN              NaN   8.742150e+04
# max       144.000000           NaN              NaN   2.448661e+06
#
#         person_emp_exp person_home_ownership     loan_amnt loan_intent  \
# count     10000.000000                 10000  1.000000e+04       10000
# ...

# %%
df['loan_status'].unique()
# Out:
# array([1, 0])

# %%
# get number of samples per class
df['loan_status'].value_counts()
# Out:
# loan_status
# 1    5000
# 0    5000
# Name: count, dtype: int64

# %% [markdown]
# Preprocessing

# %%
#Task 1:  Check null values
df.isnull().sum()
# Out:
# person_age                        0
# person_gender                     1
# person_education                  0
# person_income                     0
# person_emp_exp                    0
# person_home_ownership             0
# loan_amnt                         0
# loan_intent                       0
# loan_int_rate                     1
# loan_percent_income               1
# cb_person_cred_hist_length        0
# credit_score                      0
# previous_loan_defaults_on_file    0
# loan_status                       0
# dtype: int64

# %%
#identify categorical & numberical features having null values
#Categorical Features: gender
#Numerical Features:  loan_int_rate, loan_percent_income
# Decision : Apply Droping

# %%
df.dropna(inplace=True)
df
# Out:
#       person_age person_gender person_education  person_income  \
# 0             29        female        Associate        39704.0
# 1             28          male        Associate        36889.0
# 2             26          male        Associate        97163.0
# 3             41          male        Doctorate        65605.0
# 4             24          male         Bachelor        37030.0
# ...          ...           ...              ...            ...
# 9995          27          male         Bachelor        83946.0
# 9996          25          male           Master        38201.0
# 9997          37          male        Associate        71970.0
# 9998          28          male           Master        96968.0
# 9999          29          male           Master        44389.0
#
#       person_emp_exp person_home_ownership  loan_amnt loan_intent  \
# 0                  8                  RENT    10800.0     MEDICAL
# 1                  5                  RENT     7796.0    PERSONAL
# ...

# %%
#Check for unwanted features and remove them (eg. person_name, id, phone_number)

# %%
#Check for Duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#No Duplicates
#Decision: No need for removal of duplicates

# %%
#Check for Outliers - Numerical Only
#Numberiical: person_age, person_income, person_emp_exp,loan_amnt,  loan_int_rate, loan_percent_income, cb_person_cred_hn_int_rate', 'loan_percent_income', 'cb_person_cred_hist_length', 'credit_score']
numerical_features = ['person_age', 'person_income', 'person_emp_exp', 'loan_amnt', 'loan_int_rate', 'loan_percent_income', 'cb_person_cred_hist_length', 'credit_score']

for feature in numerical_features:
    sns.boxplot(df[feature])
    plt.title(f'Box Plot of {feature}')
    plt.show()

# %%
#Decision: Remove Outliers from all numerical features
for feature in numerical_features:
    q1, q3 = np.percentile(df[feature], [25, 75])
    iqr = q3 - q1
    minimum = q1 - 1.5 * iqr
    maximum = q3 + 1.5 * iqr
    df = df[(df[feature] >= minimum) & (df[feature] <= maximum)]
    print(f"Outliers removed from {feature}")
df
# Out:
# Outliers removed from person_age
# Outliers removed from person_income
# Outliers removed from person_emp_exp
# Outliers removed from loan_amnt
# Outliers removed from loan_int_rate
# Outliers removed from loan_percent_income
# Outliers removed from cb_person_cred_hist_length
# Outliers removed from credit_score
#       person_age person_gender person_education  person_income  \
# 0             29        female        Associate        39704.0
# 1             28          male        Associate        36889.0
# 2             26          male        Associate        97163.0
# 4             24          male         Bachelor        37030.0
# 5             37          male        Associate        58528.0
# ...          ...           ...              ...            ...
# 9994          21          male      High School        35797.0
# 9995          27          male         Bachelor        83946.0
# 9996          25          male           Master        38201.0
# ...

# %%
#Label Encode Categorical Features
# Categorical: person_gender, person_education, person_home_ownership, loan_intent,  previous_loan_defaults_on_file
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['person_gender'] = le.fit_transform(df['person_gender'])
df['person_education'] = le.fit_transform(df['person_education'])
df['person_home_ownership'] = le.fit_transform(df['person_home_ownership'])
df['loan_intent'] = le.fit_transform(df['loan_intent'])
df['previous_loan_defaults_on_file'] = le.fit_transform(df['previous_loan_defaults_on_file'])
df
# Out:
#       person_age  person_gender  person_education  person_income  \
# 0             29              0                 0        39704.0
# 1             28              1                 0        36889.0
# 2             26              1                 0        97163.0
# 4             24              1                 1        37030.0
# 5             37              1                 0        58528.0
# ...          ...            ...               ...            ...
# 9994          21              1                 3        35797.0
# 9995          27              1                 1        83946.0
# 9996          25              1                 4        38201.0
# 9998          28              1                 4        96968.0
# 9999          29              1                 4        44389.0
#
#       person_emp_exp  person_home_ownership  loan_amnt  loan_intent  \
# 0                  8                      3    10800.0            3
# ...

# %%
  #Feature Scaling- Numerical Only - MinMax Scaler
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
# df[['person_age', 'person_income', 'person_emp_exp', 'loan_amnt', 'loan_int_rate', 'loan_percent_income', 'cb_person_cred_hist_length', 'credit_score']] = scaler.fit_transform(df[['person_age', 'person_income', 'person_emp_exp', 'loan_amnt', 'loan_int_rate', 'loan_percent_income', 'cb_person_cred_hist_length', 'credit_score']])
df[numerical_features] = scaler.fit_transform(df[numerical_features])
df
# Out:
#       person_age  person_gender  person_education  person_income  \
# 0       0.473684              0                 0       0.216386
# 1       0.421053              1                 0       0.197173
# 2       0.315789              1                 0       0.608555
# 4       0.210526              1                 1       0.198135
# 5       0.894737              1                 0       0.344863
# ...          ...            ...               ...            ...
# 9994    0.052632              1                 3       0.189720
# 9995    0.368421              1                 1       0.518346
# 9996    0.263158              1                 4       0.206128
# 9998    0.421053              1                 4       0.607224
# 9999    0.473684              1                 4       0.248362
#
#       person_emp_exp  person_home_ownership  loan_amnt  loan_intent  \
# 0             0.5000                      3   0.408333            3
# ...

# %%
# Dataset Splitting for Training and testing
from sklearn.model_selection import train_test_split
X = df.drop('loan_status', axis=1)
y = df['loan_status']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state = 42)

# %%
# df size: 8494x14
#X size : 8494x13
#y size: 8494x1
#X_train = 6795x13
#Y_train = 6795x1
#X_test =1699x13
#y_test = 1699x1

# %%
print("Shape of X_train: ", X_train.shape)
print("Shape of X_test: ", X_test.shape)
print("Shape of y_train: ", y_train.shape)
print("Shape of y_test: ", y_test.shape)
# Out:
# Shape of X_train:  (6795, 13)
# Shape of X_test:  (1699, 13)
# Shape of y_train:  (6795,)
# Shape of y_test:  (1699,)

# %%
# Model Selection Training - Logistic Regression
from sklearn.linear_model import LogisticRegression  #class  import
lr = LogisticRegression() #object / instance creation
lr.fit(X_train, y_train) # Training
# Out:
# LogisticRegression()

# %%
X_test
# Out:
#       person_age  person_gender  person_education  person_income  \
# 9687    0.315789              0                 1       0.412665
# 5359    0.526316              1                 1       0.163784
# 1800    0.263158              1                 4       0.141636
# 4976    0.684211              0                 1       0.307018
# 6627    0.315789              0                 0       0.524502
# ...          ...            ...               ...            ...
# 5642    0.263158              0                 1       0.543593
# 5307    0.368421              1                 1       0.352815
# 3391    0.210526              0                 0       0.656440
# 5407    0.526316              0                 0       0.493912
# 9156    0.210526              1                 3       0.566061
#
#       person_emp_exp  person_home_ownership  loan_amnt  loan_intent  \
# 9687          0.3750                      0   0.583333            3
# ...

# %%
y_test
# Out:
# 9687    1
# 5359    1
# 1800    1
# 4976    1
# 6627    0
#        ..
# 5642    0
# 5307    0
# 3391    0
# 5407    0
# 9156    0
# Name: loan_status, Length: 1699, dtype: int64

# %%
y_pred = lr.predict(X_test) #Evaluation
y_pred
# Out:
# array([1, 1, 1, ..., 0, 1, 0])

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, y_pred))
# Out:
# 0.8775750441436139

# %%
from sklearn.metrics import confusion_matrix, classification_report
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[691 157]
#  [ 51 800]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.81      0.87       848
#            1       0.84      0.94      0.88       851
#
#     accuracy                           0.88      1699
#    macro avg       0.88      0.88      0.88      1699
# weighted avg       0.88      0.88      0.88      1699

# %%
# prompt: plot confusion matrix

import matplotlib.pyplot as plt
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=le.classes_, yticklabels=le.classes_)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
#Selected Model- kNN
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
#Test Model
y_pred = knn.predict(X_test)

# %%
#Accucary, COnfusion Matrix, Classification
print(accuracy_score(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 0.8487345497351383
# [[681 167]
#  [ 90 761]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.80      0.84       848
#            1       0.82      0.89      0.86       851
#
#     accuracy                           0.85      1699
#    macro avg       0.85      0.85      0.85      1699
# weighted avg       0.85      0.85      0.85      1699

# %%
# Model - Decision Tree Classifier
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier()
dtc.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# testing
y_pred = dtc.predict(X_test)

# %%
# Accuracy, Confusion Matrix Classification Report
print(accuracy_score(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 0.8440258975868158
# [[714 134]
#  [131 720]]
#               precision    recall  f1-score   support
#
#            0       0.84      0.84      0.84       848
#            1       0.84      0.85      0.84       851
#
#     accuracy                           0.84      1699
#    macro avg       0.84      0.84      0.84      1699
# weighted avg       0.84      0.84      0.84      1699

# %%
# Model - SVM
from sklearn.svm import SVC
svc = SVC(kernel='linear')
svc.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred = svc.predict(X_test)
print(accuracy_score(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 0.8805179517363155
# [[686 162]
#  [ 41 810]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.81      0.87       848
#            1       0.83      0.95      0.89       851
#
#     accuracy                           0.88      1699
#    macro avg       0.89      0.88      0.88      1699
# weighted avg       0.89      0.88      0.88      1699

# %%
# Model GNB
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()
nb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = nb.predict(X_test)
print(accuracy_score(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 0.8204826368452031
# [[543 305]
#  [  0 851]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.64      0.78       848
#            1       0.74      1.00      0.85       851
#
#     accuracy                           0.82      1699
#    macro avg       0.87      0.82      0.81      1699
# weighted avg       0.87      0.82      0.81      1699

# %%
#Random Forest
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200)

# %%
y_pred = rf.predict(X_test)
print(accuracy_score(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 0.8905238375515009
# [[732 116]
#  [ 70 781]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.86      0.89       848
#            1       0.87      0.92      0.89       851
#
#     accuracy                           0.89      1699
#    macro avg       0.89      0.89      0.89      1699
# weighted avg       0.89      0.89      0.89      1699

# %%
from sklearn.neural_network import MLPClassifier
#Create an MLP classifier
mlp = MLPClassifier(hidden_layer_sizes=(32,16,8,4), max_iter=1000, random_state=42)

# Train the MLP model
mlp.fit(X_train, y_train)

# Make predictions on the test set
y_pred = mlp.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
print(accuracy_score(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 0.8840494408475574
# [[736 112]
#  [ 85 766]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.87      0.88       848
#            1       0.87      0.90      0.89       851
#
#     accuracy                           0.88      1699
#    macro avg       0.88      0.88      0.88      1699
# weighted avg       0.88      0.88      0.88      1699
