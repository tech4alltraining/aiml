# %% [markdown]
# <a href="https://colab.research.google.com/github/tech4alltraining/aiml/blob/main/mlai-internship/numpy-exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
# # NumPy Master Practice Notebook
# Complete the 50 practice problems below. Write your code in the empty code cells provided under each question.

# %%
import numpy as np

# %% [markdown]
# ## 1. NumPy Creating Arrays

# %% [markdown]
# **Q1.** Create a 1D array of 5 network threat levels using integers from 1 to 5.

# %% [markdown]
# **Q2.** Create a 3x3 2D array filled entirely with zeros.

# %% [markdown]
# **Q3.** Create an array of 10 evenly spaced numbers between 0 and 1.

# %% [markdown]
# **Q4. Scenario:** You are initializing starting weights for a machine learning logistic regression model. Create a 4x4 matrix populated with random numbers between 0 and 1.

# %% [markdown]
# ## 2. NumPy Array Indexing

# %% [markdown]
# **Q5.** Given `arr = np.array([10, 20, 30, 40, 50])`, write the code to extract the 3rd element.

# %% [markdown]
# **Q6.** Given a 2D array `matrix = np.array([[120, 130], [140, 150]])`, access the value at row 1, column 0.

# %% [markdown]
# **Q7.** From a 3D array representing an RGB image, how would you access the exact Red channel value (index 0) of the pixel at coordinate (0,0)?

# %% [markdown]
# **Q8. Scenario:** A 1D array holds the mid-term scores of your C programming students. Access the score of the very last student in the roster using negative indexing.

# %% [markdown]
# ## 3. NumPy Array Slicing

# %% [markdown]
# **Q9.** Slice elements from index 1 to 4 (exclusive) in `arr = np.array([5, 10, 15, 20, 25, 30])`.

# %% [markdown]
# **Q10.** Slice the first two rows and all columns from a random 3x3 matrix.

# %% [markdown]
# **Q11.** Extract every second element (step of 2) from a 1D array of server response times: `np.array([12, 14, 15, 11, 20, 18, 10])`.

# %% [markdown]
# **Q12. Scenario:** You have a 10x10 2D array of coordinate data from a sign language detection video feed. Slice the 3x3 sub-grid from the top-right corner to isolate the hand's primary bounding box.

# %% [markdown]
# ## 4. NumPy Data Types

# %% [markdown]
# **Q13.** Create an array of strings representing file names: `['main.c', 'utils.c', 'header.h']`. Print its `.dtype`.

# %% [markdown]
# **Q14.** Create an array of integers `[1, 2, 3]` and convert it to type `float64`.

# %% [markdown]
# **Q15.** Convert the float array `np.array([1.9, 2.8, 3.1])` to integers using `astype()`. Note what happens to the decimal values.

# %% [markdown]
# **Q16. Scenario:** You received malware detection confidence scores as strings: `['0.85', '0.99', '0.12']`. Convert this array to floats, then create a boolean array where values > `0.5` are True.

# %% [markdown]
# ## 5. NumPy Copy vs View

# %% [markdown]
# **Q17.** Create an array, make a `copy()` of it, and change the first element of the copy. Print both to verify the original is untouched.

# %% [markdown]
# **Q18.** Create an array, make a `view()` of it, and change the first element of the view. Print both to verify the original was also altered.

# %% [markdown]
# **Q19.** Use the `.base` attribute to check if an array owns its data or is a view.

# %% [markdown]
# **Q20. Scenario:** You are preprocessing raw C programming exam scores. You want to normalize a subset of these scores for an experiment, but the original database array must remain perfectly intact. Write the code demonstrating whether you use a copy or a view for the subset.

# %% [markdown]
# ## 6. NumPy Array Shape

# %% [markdown]
# **Q21.** Print the shape of the 2D array `np.array([[1, 2, 3], [4, 5, 6]])`.

# %% [markdown]
# **Q22.** Create a 3D array using `ndmin=3` and print its shape.

# %% [markdown]
# **Q23.** Create a 1D array of 12 elements. What does its shape tuple look like?

# %% [markdown]
# **Q24. Scenario:** You load a frame from an OpenCV sign language video feed. The array has the shape `(1080, 1920, 3)`. Write code to extract just the number of color channels programmatically from the shape tuple.

# %% [markdown]
# ## 7. NumPy Array Reshape

# %% [markdown]
# **Q25.** Reshape a 1D array of 12 elements into a 3x4 2D matrix.

# %% [markdown]
# **Q26.** Reshape a 1D array of 8 elements into a 2x2x2 3D array.

# %% [markdown]
# **Q27.** Flatten a 3x3 2D array back into a 1D array using `reshape(-1)`.

# %% [markdown]
# **Q28. Scenario:** You have a 1D array of 784 pixel values representing a grayscale hand gesture. Reshape it into a 28x28 2D array so the convolutional layers of your model can process it spatially.

# %% [markdown]
# ## 8. NumPy Array Iterating

# %% [markdown]
# **Q29.** Iterate through a 1D array and print each element.

# %% [markdown]
# **Q30.** Iterate through a 2D array using a standard `for` loop and print each row.

# %% [markdown]
# **Q31.** Use `np.nditer()` to iterate through every single scalar element of a 3D array efficiently.

# %% [markdown]
# **Q32. Scenario:** You have a 2D array of network ports mapped against scanned IP addresses. Iterate through the array using `np.ndenumerate()` to print the exact 2D index coordinate and value of each port scan result.

# %% [markdown]
# ## 9. NumPy Array Join

# %% [markdown]
# **Q33.** Concatenate two 1D arrays: `[1, 2]` and `[3, 4]` using `np.concatenate()`.

# %% [markdown]
# **Q34.** Stack two 1D arrays vertically to create a 2D array using `np.vstack()`.

# %% [markdown]
# **Q35.** Stack two 1D arrays horizontally using `np.hstack()`.

# %% [markdown]
# **Q36. Scenario:** You have two 2D arrays of shape (50, 2); one contains student scores for the Midterm, and the other for the Final exam. Join them along `axis=1` to create a master gradebook matrix of shape (50, 4).

# %% [markdown]
# ## 10. NumPy Array Split

# %% [markdown]
# **Q37.** Split a 1D array of 6 elements into 3 equal parts using `np.array_split()`.

# %% [markdown]
# **Q38.** Use `np.array_split()` on a 1D array of 7 elements to split it into 3 parts. Observe how it handles the unequal division.

# %% [markdown]
# **Q39.** Split a 2D array (4x4) into two 2x4 arrays along the row axis (`axis=0`).

# %% [markdown]
# **Q40. Scenario:** A chunk-wise aggregated feature estimation algorithm (like CAFÉ-GB) needs to process training features in batches. Split a 1D array of 100 feature mappings into exactly 5 equal chunks.

# %% [markdown]
# ## 11. NumPy Array Search

# %% [markdown]
# **Q41.** Find the indices where the value is exactly 5 in the array `arr = np.array([1, 5, 2, 5, 3])` using `np.where()`.

# %% [markdown]
# **Q42.** Find the indices of all even numbers in a 1D array of integers.

# %% [markdown]
# **Q43. Scenario:** In an array of cybersecurity threat scores (0.0 to 10.0), use `np.where()` to find the exact indices of all "critical" threats (score >= 9.0) so those IPs can be isolated.

# %% [markdown]
# ## 12. NumPy Array Sort

# %% [markdown]
# **Q44.** Sort a 1D array of random integers in ascending order using `np.sort()`.

# %% [markdown]
# **Q45.** Sort an array of strings (e.g., `['banana', 'apple', 'cherry']`) alphabetically.

# %% [markdown]
# **Q46. Scenario:** You have a 2D array where each row represents a student and columns represent their 3 quiz scores. Sort the array along `axis=1` so each student's scores are ordered from lowest to highest.

# %% [markdown]
# ## 13. NumPy Array Filter

# %% [markdown]
# **Q47.** Create a boolean filter array manually to extract only elements greater than 10 from `arr = np.array([5, 12, 8, 20])`.

# %% [markdown]
# **Q48.** Filter a 1D array to keep only the positive numbers using direct boolean indexing (e.g., `arr[arr > 0]`).

# %% [markdown]
# **Q49. Scenario:** You have an array of image pixel intensities `[120, 250, 45, 200, 10]`. Apply a mask to filter out all background pixels (values < 50) and keep only the bright features.

# %% [markdown]
# **Q50. Scenario:** Given an array of final C programming exam scores, create a new array containing only the passing grades (score >= 60) without using any loops.
