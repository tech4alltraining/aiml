# %% [markdown]
# <a href="https://colab.research.google.com/github/tech4alltraining/aiml/blob/main/mlai-internship/matplotlib-seaborn-exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
# # Matplotlib & Seaborn Master Practice Notebook
# Complete the 50 practice problems below. Write your code in the empty code cells provided under each question.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# Generate some sample data for later use
np.random.seed(42)
mock_df = pd.DataFrame({
    'Epoch': np.arange(1, 101),
    'Loss': np.exp(-np.arange(1, 101)/20) + np.random.normal(0, 0.05, 100),
    'Accuracy': 1 - np.exp(-np.arange(1, 101)/20) + np.random.normal(0, 0.02, 100),
    'Malware_Score': np.random.uniform(0, 100, 100),
    'CPU_Usage': np.random.uniform(10, 90, 100),
    'Category': np.random.choice(['Trojan', 'Ransomware', 'Spyware', 'Adware'], 100)
})

# %% [markdown]
# ## Matplotlib Plotting

# %% [markdown]
# **Q1. Scenario:** You are tracking the loss of a machine learning model. Plot `x = [1, 2, 3, 4, 5]` against `y = [2.5, 1.8, 1.2, 0.8, 0.5]` using a basic Matplotlib line plot.

# %% [markdown]
# **Q2.** Plot only the `y` values `[10, 20, 15, 25, 30]`. Let Matplotlib automatically generate the x-axis index values.

# %% [markdown]
# ## Matplotlib Markers

# %% [markdown]
# **Q3. Scenario:** You want to highlight specific spikes in network traffic. Plot `y = [100, 500, 150, 600, 200]` and add a circular marker (`'o'`) to each data point.

# %% [markdown]
# **Q4.** Format the markers from Q3 to be red stars (`'*'`), with a marker size (`ms`) of 15.

# %% [markdown]
# ## Matplotlib Line

# %% [markdown]
# **Q5. Scenario:** You are drawing a critical threat threshold line. Plot a horizontal line across the graph at y=85, making it a dotted line (`ls=':'`) and color it red (`c='r'`).

# %% [markdown]
# ## Matplotlib Labels

# %% [markdown]
# **Q6. Scenario:** You plotted your C programming students' grades. Now, add an x-label ("Student ID"), a y-label ("Final Grade"), and a title ("C Programming Final Results").

# %% [markdown]
# **Q7.** Enhance the labels from Q6 by passing a `fontdict` to make the title font size 18, color blue, and bold.

# %% [markdown]
# ## Matplotlib Grid

# %% [markdown]
# **Q8. Scenario:** You are viewing a computer vision model's accuracy curve and need precise readings. Add a background grid to your plot using `plt.grid()`.

# %% [markdown]
# **Q9.** Modify the grid to only show horizontal lines (y-axis grid), making the lines dashed and gray.

# %% [markdown]
# ## Matplotlib Subplot

# %% [markdown]
# **Q10. Scenario:** You want to compare Training Loss and Validation Loss side-by-side. Create a 1x2 subplot layout. Plot `x=[1,2,3], y=[3,2,1]` on the left, and `x=[1,2,3], y=[3.2, 2.5, 1.8]` on the right.

# %% [markdown]
# **Q11.** Add a main super-title (`plt.suptitle()`) above the subplots from Q10 saying "Model Performance Evaluation".

# %% [markdown]
# ## Matplotlib Scatter

# %% [markdown]
# **Q12. Scenario:** You are looking for a correlation between File Size (x) and Malware Scan Time (y). Plot a Matplotlib scatter plot using two arrays of 10 random numbers.

# %% [markdown]
# ## Matplotlib Bars

# %% [markdown]
# **Q13. Scenario:** Visualize the number of students who got A, B, C, and D grades. Plot a vertical bar chart with `x = ['A', 'B', 'C', 'D']` and `y = [15, 25, 10, 5]`.

# %% [markdown]
# **Q14. Scenario:** Visualizing the top 5 Malware types detected. Plot a **horizontal** bar chart (`barh`) using `x = ['Trojan', 'Worm', 'Ransomware', 'Spyware', 'Adware']` and counts `[50, 30, 45, 10, 20]`.

# %% [markdown]
# ## Matplotlib Histograms

# %% [markdown]
# **Q15. Scenario:** You extracted 1,000 grayscale pixel intensities (0-255) from a sign language detection frame using OpenCV. Generate an array of 1000 random ints between 0-255 and plot a histogram with 20 bins.

# %% [markdown]
# ## Matplotlib Pie Charts

# %% [markdown]
# **Q16. Scenario:** Show the OS distribution of infected machines. Create a pie chart with values `[45, 25, 20, 10]` and labels `['Windows', 'Linux', 'macOS', 'Android']`. Include the `autopct='%1.1f%%'` parameter to show percentages.

# %% [markdown]
# ## Plotting Graph Using Seaborn

# %% [markdown]
# **Q17.** Import Seaborn as `sns` and plot a basic line plot using `sns.lineplot()` comparing 'Epoch' (x) and 'Loss' (y) from the `mock_df` provided in the imports cell.

# %% [markdown]
# ## Using Seaborn with Matplotlib

# %% [markdown]
# **Q18. Scenario:** Seaborn builds on top of Matplotlib. Create a Seaborn `sns.scatterplot()` using 'CPU_Usage' and 'Malware_Score' from `mock_df`. Then, use Matplotlib's `plt.title()` to add the title "CPU vs Threat Score".

# %% [markdown]
# ## Customizing Seaborn Plots

# %% [markdown]
# **Q19.** Change the default aesthetic of Seaborn to the "darkgrid" theme using `sns.set_style()`. Then replot the lineplot from Q17 to see the difference.

# %% [markdown]
# ## Grids and Multi-Plot Layouts

# %% [markdown]
# **Q20. Scenario:** You want to separate malware CPU usage by Category. Create a `sns.FacetGrid` using `mock_df` with `col="Category"`, and map a `sns.histplot` of 'CPU_Usage' onto the grid.

# %% [markdown]
# ## Relational Plots I

# %% [markdown]
# **Q21.** Use Seaborn's high-level `sns.relplot()` to create a scatter plot (the default kind) of 'Epoch' vs 'Accuracy' from `mock_df`.

# %% [markdown]
# ## Relational Plots II

# %% [markdown]
# **Q22.** Modify the `relplot` from Q21. Change `kind="line"` and use the `col="Category"` parameter to generate 4 separate line charts for each malware category side-by-side.

# %% [markdown]
# ## Scatterplot

# %% [markdown]
# **Q23.** Directly use `sns.scatterplot()` to plot 'Malware_Score' (x) vs 'CPU_Usage' (y) from `mock_df`.

# %% [markdown]
# ## Visualizing Relationships with Scatter Plots

# %% [markdown]
# **Q24. Scenario:** Add another dimension to your scatter plot. In the previous scatterplot, set the `hue` parameter to 'Category' to color-code the points by the type of malware.

# %% [markdown]
# **Q25.** Enhance the scatter plot further by setting both `hue="Category"` and `size="Accuracy"` so that larger points indicate higher accuracy.

# %% [markdown]
# ## Scatter Plot with Regression Line

# %% [markdown]
# **Q26. Scenario:** You want to see the linear trend between Epoch and Accuracy. Use `sns.regplot()` to plot a scatter plot that automatically fits and draws a linear regression line.

# %% [markdown]
# ## Scatter Plot with Marginal Histograms

# %% [markdown]
# **Q27. Scenario:** You need to see both the relationship between CPU Usage and Malware Score, AND their individual distributions. Use `sns.jointplot()` to achieve this.

# %% [markdown]
# ## Line Plot with Seaborn

# %% [markdown]
# **Q28. Scenario:** `sns.lineplot` automatically aggregates data and shows confidence intervals if there are multiple y values for an x value. Simulate this by plotting 'Category' on the x-axis and 'Loss' on the y-axis to see the average loss per category.

# %% [markdown]
# ## Time Series Plot with Seaborn and Pandas

# %% [markdown]
# **Q29. Scenario:** Let's pretend the 'Epoch' column in `mock_df` represents days. Create a new column 'Date' using `pd.date_range('2026-01-01', periods=100)`. Then plot a `sns.lineplot()` with 'Date' on the x-axis and 'Loss' on the y-axis.

# %% [markdown]
# ## Time Series Plot with Rolling Average

# %% [markdown]
# **Q30. Scenario:** The loss curve is too noisy. Use Pandas `.rolling(window=5).mean()` to calculate a moving average of 'Loss'. Add it to `mock_df` as 'Rolling_Loss', and plot both 'Loss' and 'Rolling_Loss' on the same graph using Seaborn.

# %% [markdown]
# ## Barplot

# %% [markdown]
# **Q31.** Use `sns.barplot()` to show the average 'CPU_Usage' (y) for each malware 'Category' (x).

# %% [markdown]
# **Q32.** Modify the barplot from Q31 by changing the aggregation function. Pass `estimator=np.median` to show the median CPU usage instead of the mean.

# %% [markdown]
# ## Countplot

# %% [markdown]
# **Q33. Scenario:** You simply want to count how many instances of each malware Category exist in the dataset. Use `sns.countplot(x='Category', data=mock_df)`.

# %% [markdown]
# ## Boxplot

# %% [markdown]
# **Q34. Scenario:** Analyze the distribution and detect outliers in your algorithmic execution times. Use `sns.boxplot()` with x='Category' and y='CPU_Usage'.

# %% [markdown]
# ## Violinplot

# %% [markdown]
# **Q35. Scenario:** A boxplot hides the underlying density shape. Replace the boxplot from Q34 with `sns.violinplot()` to see the probability density of CPU usage per malware category.

# %% [markdown]
# ## Stripplot

# %% [markdown]
# **Q36. Scenario:** You want to see every single individual data point, not just summaries. Plot a `sns.stripplot()` showing 'CPU_Usage' broken down by 'Category'.

# %% [markdown]
# ## Swarmplot

# %% [markdown]
# **Q37. Scenario:** Stripplots overlap points. To prevent this, use `sns.swarmplot(x='Category', y='CPU_Usage')` so the data points spread out horizontally to show density.

# %% [markdown]
# **Q38. Scenario:** A powerful analytical visualization overlay. Create a `sns.boxplot()` first, and then in the very next line of code, create a `sns.swarmplot()` using the same x and y. Make the swarmplot dots black (`color="0.25"`) so they stand out against the boxplot.

# %% [markdown]
# ## Factorplot (Catplot)

# %% [markdown]
# **Q39. Note:** `factorplot` was renamed to `catplot` in newer Seaborn versions. Use `sns.catplot()` with `kind="bar"` to plot 'Category' vs 'Malware_Score'.

# %% [markdown]
# **Q40.** Use `sns.catplot()` again, but this time set `kind="box"`. Notice how it acts as a figure-level wrapper for boxplots.

# %% [markdown]
# ## Histograms

# %% [markdown]
# **Q41. Scenario:** Analyze the distribution of your model's accuracy. Plot a Seaborn histogram using `sns.histplot(data=mock_df, x="Accuracy")`.

# %% [markdown]
# **Q42.** Enhance the histogram from Q41 by setting the `kde=True` parameter to overlay a Kernel Density Estimation line on top of the bars.

# %% [markdown]
# ## Jointplot

# %% [markdown]
# **Q43.** Earlier we used a scatter jointplot. Now, use `sns.jointplot()` for 'Malware_Score' and 'CPU_Usage', but change the internal plot style to a 2D density plot by passing `kind="kde"`.

# %% [markdown]
# **Q44.** Change the jointplot style again. This time set `kind="hex"` to create a hexbin plot mapping density.

# %% [markdown]
# ## Pairplot

# %% [markdown]
# **Q45. Scenario:** You are doing exploratory data analysis (EDA) on a new malware dataset and want to see the correlation between ALL numeric features instantly. Use `sns.pairplot(mock_df)`.

# %% [markdown]
# **Q46.** Modify the pairplot. Pass `hue="Category"` so that every subplot in the matrix is color-coded by the malware type, revealing separated clusters.

# %% [markdown]
# ## KDE Plot

# %% [markdown]
# **Q47.** Create an isolated Kernel Density Estimate plot using `sns.kdeplot()` for the 'Accuracy' column. Turn on the shading under the curve by setting `fill=True`.

# %% [markdown]
# ## Heatmap

# %% [markdown]
# **Q48. Scenario:** You have generated a confusion matrix for your Computer Vision model. Create a 3x3 Numpy array of integers, and plot it using `sns.heatmap()`.

# %% [markdown]
# **Q49.** Customize the confusion matrix heatmap from Q48. Set `annot=True` so the numerical values appear inside the squares, and set `cmap="Blues"` for a blue color palette.

# %% [markdown]
# ## Correlation Heatmap

# %% [markdown]
# **Q50. Scenario:** Identify highly correlated features that might cause collinearity in your machine learning model. First, calculate the correlation matrix of only the numeric columns in `mock_df` using `.corr()`. Then, pass that matrix into `sns.heatmap()` with `annot=True` and `cmap="coolwarm"` to visualize the positive/negative correlations.
