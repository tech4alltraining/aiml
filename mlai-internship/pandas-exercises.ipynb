# %% [markdown]
# # Pandas Master Practice Notebook
# Complete the 50 practice problems below. Write your code in the empty code cells provided under each question.
# <a href="https://colab.research.google.com/github/tech4alltraining/aiml/blob/main/mlai-internship/pandas-exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Pandas Series

# %% [markdown]
# **Q1.** Create a Pandas Series from a standard Python list of malware severity scores: `[9.5, 8.2, 4.1, 7.7]`.

# %% [markdown]
# **Q2.** Create a Pandas Series from a dictionary mapping IP addresses (keys) to threat levels (values).

# %% [markdown]
# **Q3. Scenario:** You have a Series of C programming exam grades. Write the code to extract only the 3rd grade using its index position.

# %% [markdown]
# **Q4.** Create a Series of 5 numbers, but assign custom string labels as the index (e.g., 'Student_A', 'Student_B').

# %% [markdown]
# ## 2. Pandas DataFrames

# %% [markdown]
# **Q5.** Create a DataFrame from a dictionary containing three keys: 'StudentID', 'Score', and 'Attendance'.

# %% [markdown]
# **Q6.** Extract and print just the 'Score' column from the DataFrame created in Q5.

# %% [markdown]
# **Q7. Scenario:** You want to look at a specific student's full record. Use `.iloc` or `.loc` to extract the entire second row of the DataFrame.

# %% [markdown]
# **Q8.** Add a new column named 'Pass/Fail' to your DataFrame that evaluates to True if 'Score' > 60, and False otherwise.

# %% [markdown]
# **Q9.** Delete the 'Attendance' column completely from the DataFrame.

# %% [markdown]
# ## 3. Pandas Read CSV

# %% [markdown]
# **Q10.** Write the code to load a standard CSV file named `server_logs.csv` into a Pandas DataFrame.

# %% [markdown]
# **Q11. Scenario:** You are working with a massive `malware_dataset.csv` that crashes memory. Read only the first 500 rows.

# %% [markdown]
# **Q12. Scenario:** Your `raw_data.csv` lacks a header row. Read the file and assign custom column names: `['Feature1', 'Feature2', 'Label']` simultaneously.

# %% [markdown]
# ## 4. Pandas Read JSON

# %% [markdown]
# **Q13.** Write the code to load a JSON file named `student_profiles.json` into a DataFrame.

# %% [markdown]
# **Q14.** Convert a Python dictionary containing nested lists into a Pandas DataFrame using `pd.DataFrame.from_dict()`.

# %% [markdown]
# **Q15. Scenario:** You received API response data in JSON format, but the data is deeply nested. Use `pd.json_normalize()` to flatten a complex JSON object.

# %% [markdown]
# ## 5. Pandas Analyzing Data

# %% [markdown]
# **Q16.** Display the first 10 rows of a loaded dataset to quickly inspect the headers.

# %% [markdown]
# **Q17.** Display the final 5 rows of a dataset.

# %% [markdown]
# **Q18. Scenario:** You need a high-level overview of column names, non-null counts, and memory usage. Print the dataset's `.info()`.

# %% [markdown]
# **Q19.** Generate statistical summaries (mean, min, max, quartiles) for all numeric columns in the dataset using a single method.

# %% [markdown]
# **Q20.** Print the exact dimensions (rows and columns) of your feature matrix DataFrame.

# %% [markdown]
# ## 6. Cleaning Data (Overview)

# %% [markdown]
# **Q21.** Check which columns in your DataFrame contain missing values (NaN) by returning a boolean DataFrame.

# %% [markdown]
# **Q22.** Calculate the exact sum of missing values for each individual column.

# %% [markdown]
# **Q23.** Drop all rows from the DataFrame where *any* column has a missing value.

# %% [markdown]
# **Q24. Scenario:** A dataset contains a highly sparse column that disrupts your ML model. Write the code to drop an entire column (e.g., 'Useless_Feature') permanently.

# %% [markdown]
# ## 7. Cleaning Empty Cells

# %% [markdown]
# **Q25.** Fill all empty cells (NaN) across the entire DataFrame with the value `0`.

# %% [markdown]
# **Q26. Scenario:** Several students missed an exam. Fill missing values in just the 'Score' column with the calculated mean of that specific column.

# %% [markdown]
# **Q27.** Perform a forward-fill (`ffill`) to replace missing values in a time-series 'Server_Load' column with the previous valid row's value.

# %% [markdown]
# **Q28.** Perform a backward-fill (`bfill`) to replace missing values using the next row's value.

# %% [markdown]
# ## 8. Cleaning Wrong Format

# %% [markdown]
# **Q29.** Convert a 'Date_Joined' column that is currently stored as text strings into Pandas datetime format.

# %% [markdown]
# **Q30. Scenario:** Due to a parsing error, network threat levels were logged as strings with commas (e.g., "1,000"). Remove the commas and convert the column to integers.

# %% [markdown]
# **Q31.** Remove rows where the 'Timestamp' column failed to convert to datetime and resulted in a `NaT` value.

# %% [markdown]
# **Q32.** Convert all string values in a 'Student_Name' column to uppercase for formatting consistency.

# %% [markdown]
# ## 9. Cleaning Wrong Data

# %% [markdown]
# **Q33.** Find values in an 'Age' column that are greater than 120 and replace them with the median age of the dataset.

# %% [markdown]
# **Q34. Scenario:** In your grading system, any score above 100 is a data entry error. Write code to cap all values in the 'Score' column at exactly 100.

# %% [markdown]
# **Q35.** Delete all rows where the 'Department' column is explicitly labeled as the string 'Unknown'.

# %% [markdown]
# **Q36.** Fix a persistent typo: Replace all instances of 'Malwar' with 'Malware' in the 'Threat_Category' column.

# %% [markdown]
# ## 10. Removing Duplicates

# %% [markdown]
# **Q37.** Write the code to identify and count the total number of perfectly duplicated rows in a DataFrame.

# %% [markdown]
# **Q38.** Drop all duplicate rows from the DataFrame `inplace`.

# %% [markdown]
# **Q39. Scenario:** A network log shows multiple connection attempts from the same IP address. Drop duplicates based *only* on the 'IP_Address' column, keeping the first occurrence.

# %% [markdown]
# **Q40.** Drop duplicates based on 'Student_ID' but ensure you keep the *last* occurrence instead of the first.

# %% [markdown]
# ## 11. Pandas Correlations

# %% [markdown]
# **Q41.** Calculate the standard Pearson correlation matrix for all numeric columns in your DataFrame.

# %% [markdown]
# **Q42.** Extract and print just the specific correlation coefficient between 'Hours_Studied' and 'Final_Score'.

# %% [markdown]
# **Q43. Scenario:** You are checking for feature correlation in malware data. Write the code to find which numeric feature has the highest correlation with 'Is_Malicious' (excluding 'Is_Malicious' itself).

# %% [markdown]
# **Q44.** Compute the Spearman rank correlation matrix for data that has non-linear relationships.

# %% [markdown]
# **Q45.** Filter the output of a correlation matrix to only show values greater than `0.7` or less than `-0.7` (strong correlations).

# %% [markdown]
# ## 12. Pandas Plotting

# %% [markdown]
# **Q46.** Plot a basic line graph of 'Server_CPU_Usage' using the built-in `.plot()` method.

# %% [markdown]
# **Q47.** Create a scatter plot comparing 'Midterm_Score' (x-axis) vs 'Final_Score' (y-axis).

# %% [markdown]
# **Q48. Scenario:** You want to visually analyze the distribution of grades. Plot a histogram of the 'C_Programming_Scores' column.

# %% [markdown]
# **Q49.** Plot a bar chart showing the frequency count of different 'Threat_Types' in a security log.

# %% [markdown]
# **Q50.** Create a boxplot of 'Response_Times' to visually identify outlier latency spikes in your system data.
